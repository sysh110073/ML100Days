# %% [markdown]
# ## Work
# 1. 試比較 save_best_only 與否的差異
# 2. 請僅存入將 save_weights_only 設定為 True, 並嘗試 reset ipynb 並將模型與權重重新建回並預測 x_test

# %%
import os
from tensorflow import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95

save_best_only = [True, False]

# %%
# 載入 Callbacks
"""Code Here
設定 callbacks: model checkpoint
"""
from keras.callbacks import ModelCheckpoint

results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""

for S_B in save_best_only:
    keras.backend.clear_session() # 把舊的 Graph 清掉
    model_ckpt = ModelCheckpoint(filepath="./tmp.h5", 
                             monitor="val_loss", 
                             save_best_only=S_B)
    
    print("save_best_only-%s" % str(S_B))
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)
    model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[model_ckpt]
         )
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    exp_name_tag = "save_best_only-%s" % str(S_B)
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}    
    # Load back
    model = keras.models.load_model("./tmp.h5")
    loss_loadback, acc_loadback = model.evaluate(x_test, y_test)
# Out:
# save_best_only-True
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# c:\Users\huang\anaconda3\lib\site-packages\keras\optimizer_v2\gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/50
# 49/49 [==============================] - 2s 34ms/step - loss: 2.2394 - accuracy: 0.2617 - val_loss: 2.1043 - val_accuracy: 0.2053
# Epoch 2/50
# 49/49 [==============================] - 1s 30ms/step - loss: 1.7528 - accuracy: 0.3922 - val_loss: 1.9605 - val_accuracy: 0.2987
# Epoch 3/50
# 49/49 [==============================] - 1s 29ms/step - loss: 1.6273 - accuracy: 0.4317 - val_loss: 1.8275 - val_accuracy: 0.3635
# Epoch 4/50
# 49/49 [==============================] - 1s 31ms/step - loss: 1.5524 - accuracy: 0.4577 - val_loss: 1.7248 - val_accuracy: 0.4038
# Epoch 5/50
# 49/49 [==============================] - 1s 30ms/step - loss: 1.4970 - accuracy: 0.4775 - val_loss: 1.6537 - val_accuracy: 0.4225
# Epoch 6/50
# 49/49 [==============================] - 2s 31ms/step - loss: 1.4529 - accuracy: 0.4921 - val_loss: 1.5887 - val_accuracy: 0.4455
# Epoch 7/50
# 49/49 [==============================] - 2s 31ms/step - loss: 1.4132 - accuracy: 0.5079 - val_loss: 1.5498 - val_accuracy: 0.4559
# Epoch 8/50
# 49/49 [==============================] - 1s 30ms/step - loss: 1.3780 - accuracy: 0.5201 - val_loss: 1.5261 - val_accuracy: 0.4643
# Epoch 9/50
# 49/49 [==============================] - 1s 30ms/step - loss: 1.3454 - accuracy: 0.5307 - val_loss: 1.5176 - val_accuracy: 0.4664
# Epoch 10/50
# 49/49 [==============================] - 2s 31ms/step - loss: 1.3131 - accuracy: 0.5450 - val_loss: 1.4956 - val_accuracy: 0.4808
# Epoch 11/50
# 49/49 [==============================] - 2s 32ms/step - loss: 1.2847 - accuracy: 0.5545 - val_loss: 1.4859 - val_accuracy: 0.4813
# Epoch 12/50
# 49/49 [==============================] - 2s 32ms/step - loss: 1.2584 - accuracy: 0.5639 - val_loss: 1.4805 - val_accuracy: 0.4790
# Epoch 13/50
# 49/49 [==============================] - 2s 31ms/step - loss: 1.2315 - accuracy: 0.5753 - val_loss: 1.4790 - val_accuracy: 0.4824
# Epoch 14/50
# 49/49 [==============================] - 2s 32ms/step - loss: 1.2064 - accuracy: 0.5836 - val_loss: 1.4765 - val_accuracy: 0.4863
# Epoch 15/50
# 49/49 [==============================] - 2s 31ms/step - loss: 1.1817 - accuracy: 0.5946 - val_loss: 1.4623 - val_accuracy: 0.4911
# Epoch 16/50
# 49/49 [==============================] - 1s 30ms/step - loss: 1.1563 - accuracy: 0.6044 - val_loss: 1.4653 - val_accuracy: 0.4898
# Epoch 17/50
# 49/49 [==============================] - 1s 30ms/step - loss: 1.1333 - accuracy: 0.6126 - val_loss: 1.4571 - val_accuracy: 0.4903
# Epoch 18/50
# 49/49 [==============================] - 1s 29ms/step - loss: 1.1109 - accuracy: 0.6205 - val_loss: 1.4587 - val_accuracy: 0.4912
# Epoch 19/50
# 49/49 [==============================] - 1s 30ms/step - loss: 1.0878 - accuracy: 0.6277 - val_loss: 1.4570 - val_accuracy: 0.4924
# Epoch 20/50
# 49/49 [==============================] - 1s 29ms/step - loss: 1.0674 - accuracy: 0.6364 - val_loss: 1.4592 - val_accuracy: 0.4968
# Epoch 21/50
# 49/49 [==============================] - 1s 30ms/step - loss: 1.0433 - accuracy: 0.6460 - val_loss: 1.4589 - val_accuracy: 0.4957
# Epoch 22/50
# 49/49 [==============================] - 1s 30ms/step - loss: 1.0214 - accuracy: 0.6560 - val_loss: 1.4610 - val_accuracy: 0.4960
# Epoch 23/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.9997 - accuracy: 0.6629 - val_loss: 1.4556 - val_accuracy: 0.4963
# Epoch 24/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.9769 - accuracy: 0.6735 - val_loss: 1.4449 - val_accuracy: 0.5039
# Epoch 25/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.9562 - accuracy: 0.6789 - val_loss: 1.4647 - val_accuracy: 0.4988
# Epoch 26/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.9373 - accuracy: 0.6880 - val_loss: 1.4617 - val_accuracy: 0.5015
# Epoch 27/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.9141 - accuracy: 0.6960 - val_loss: 1.4768 - val_accuracy: 0.4977
# Epoch 28/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.8938 - accuracy: 0.7031 - val_loss: 1.4871 - val_accuracy: 0.4968
# Epoch 29/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.8739 - accuracy: 0.7109 - val_loss: 1.4934 - val_accuracy: 0.4994
# Epoch 30/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.8518 - accuracy: 0.7198 - val_loss: 1.4856 - val_accuracy: 0.5014
# Epoch 31/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.8334 - accuracy: 0.7279 - val_loss: 1.4914 - val_accuracy: 0.4972
# Epoch 32/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.8120 - accuracy: 0.7362 - val_loss: 1.4921 - val_accuracy: 0.5006
# Epoch 33/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.7927 - accuracy: 0.7454 - val_loss: 1.5007 - val_accuracy: 0.5001
# Epoch 34/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.7721 - accuracy: 0.7509 - val_loss: 1.5023 - val_accuracy: 0.4999
# Epoch 35/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.7539 - accuracy: 0.7604 - val_loss: 1.5205 - val_accuracy: 0.4988
# Epoch 36/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.7340 - accuracy: 0.7658 - val_loss: 1.5189 - val_accuracy: 0.4946
# Epoch 37/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.7157 - accuracy: 0.7754 - val_loss: 1.5404 - val_accuracy: 0.4872
# Epoch 38/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.6966 - accuracy: 0.7808 - val_loss: 1.5562 - val_accuracy: 0.4901
# Epoch 39/50
# 49/49 [==============================] - 1s 28ms/step - loss: 0.6758 - accuracy: 0.7890 - val_loss: 1.5623 - val_accuracy: 0.4941
# Epoch 40/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.6568 - accuracy: 0.7991 - val_loss: 1.5562 - val_accuracy: 0.4974
# Epoch 41/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.6415 - accuracy: 0.8036 - val_loss: 1.5728 - val_accuracy: 0.4912
# Epoch 42/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.6230 - accuracy: 0.8110 - val_loss: 1.5869 - val_accuracy: 0.4944
# Epoch 43/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.6050 - accuracy: 0.8182 - val_loss: 1.5853 - val_accuracy: 0.4910
# Epoch 44/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.5868 - accuracy: 0.8263 - val_loss: 1.6087 - val_accuracy: 0.4931
# Epoch 45/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.5715 - accuracy: 0.8307 - val_loss: 1.6168 - val_accuracy: 0.4854
# Epoch 46/50
# 49/49 [==============================] - 2s 31ms/step - loss: 0.5536 - accuracy: 0.8381 - val_loss: 1.6244 - val_accuracy: 0.4903
# Epoch 47/50
# 49/49 [==============================] - 2s 31ms/step - loss: 0.5342 - accuracy: 0.8474 - val_loss: 1.6395 - val_accuracy: 0.4885
# Epoch 48/50
# 49/49 [==============================] - 2s 31ms/step - loss: 0.5184 - accuracy: 0.8528 - val_loss: 1.6524 - val_accuracy: 0.4933
# Epoch 49/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.5018 - accuracy: 0.8589 - val_loss: 1.6617 - val_accuracy: 0.4855
# Epoch 50/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.4857 - accuracy: 0.8650 - val_loss: 1.6808 - val_accuracy: 0.4942
# 313/313 [==============================] - 1s 2ms/step - loss: 1.4449 - accuracy: 0.5039
# save_best_only-False
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/50
# 49/49 [==============================] - 2s 33ms/step - loss: 2.1931 - accuracy: 0.2748 - val_loss: 2.1120 - val_accuracy: 0.2296
# Epoch 2/50
# 49/49 [==============================] - 1s 30ms/step - loss: 1.7398 - accuracy: 0.3915 - val_loss: 1.9464 - val_accuracy: 0.3223
# Epoch 3/50
# 49/49 [==============================] - 1s 30ms/step - loss: 1.6201 - accuracy: 0.4321 - val_loss: 1.8198 - val_accuracy: 0.3714
# Epoch 4/50
# 49/49 [==============================] - 1s 30ms/step - loss: 1.5496 - accuracy: 0.4586 - val_loss: 1.7250 - val_accuracy: 0.4058
# Epoch 5/50
# 49/49 [==============================] - 1s 29ms/step - loss: 1.4961 - accuracy: 0.4778 - val_loss: 1.6422 - val_accuracy: 0.4280
# Epoch 6/50
# 49/49 [==============================] - 1s 29ms/step - loss: 1.4530 - accuracy: 0.4942 - val_loss: 1.5803 - val_accuracy: 0.4503
# Epoch 7/50
# 49/49 [==============================] - 1s 29ms/step - loss: 1.4141 - accuracy: 0.5082 - val_loss: 1.5430 - val_accuracy: 0.4576
# Epoch 8/50
# 49/49 [==============================] - 1s 30ms/step - loss: 1.3779 - accuracy: 0.5203 - val_loss: 1.5218 - val_accuracy: 0.4641
# Epoch 9/50
# 49/49 [==============================] - 1s 29ms/step - loss: 1.3465 - accuracy: 0.5326 - val_loss: 1.5023 - val_accuracy: 0.4705
# Epoch 10/50
# 49/49 [==============================] - 1s 29ms/step - loss: 1.3150 - accuracy: 0.5441 - val_loss: 1.4914 - val_accuracy: 0.4748
# Epoch 11/50
# 49/49 [==============================] - 1s 29ms/step - loss: 1.2885 - accuracy: 0.5531 - val_loss: 1.4747 - val_accuracy: 0.4809
# Epoch 12/50
# 49/49 [==============================] - 1s 30ms/step - loss: 1.2600 - accuracy: 0.5638 - val_loss: 1.4761 - val_accuracy: 0.4742
# Epoch 13/50
# 49/49 [==============================] - 1s 29ms/step - loss: 1.2360 - accuracy: 0.5712 - val_loss: 1.4739 - val_accuracy: 0.4808
# Epoch 14/50
# 49/49 [==============================] - 1s 29ms/step - loss: 1.2092 - accuracy: 0.5824 - val_loss: 1.4575 - val_accuracy: 0.4832
# Epoch 15/50
# 49/49 [==============================] - 2s 31ms/step - loss: 1.1858 - accuracy: 0.5908 - val_loss: 1.4616 - val_accuracy: 0.4892
# Epoch 16/50
# 49/49 [==============================] - 1s 30ms/step - loss: 1.1633 - accuracy: 0.5995 - val_loss: 1.4637 - val_accuracy: 0.4863
# Epoch 17/50
# 49/49 [==============================] - 1s 30ms/step - loss: 1.1381 - accuracy: 0.6086 - val_loss: 1.4536 - val_accuracy: 0.4922
# Epoch 18/50
# 49/49 [==============================] - 1s 29ms/step - loss: 1.1162 - accuracy: 0.6172 - val_loss: 1.4542 - val_accuracy: 0.4909
# Epoch 19/50
# 49/49 [==============================] - 1s 29ms/step - loss: 1.0945 - accuracy: 0.6258 - val_loss: 1.4614 - val_accuracy: 0.4927
# Epoch 20/50
# 49/49 [==============================] - 1s 29ms/step - loss: 1.0725 - accuracy: 0.6337 - val_loss: 1.4561 - val_accuracy: 0.4932
# Epoch 21/50
# 49/49 [==============================] - 1s 29ms/step - loss: 1.0517 - accuracy: 0.6418 - val_loss: 1.4608 - val_accuracy: 0.4886
# Epoch 22/50
# 49/49 [==============================] - 1s 30ms/step - loss: 1.0284 - accuracy: 0.6518 - val_loss: 1.4635 - val_accuracy: 0.4935
# Epoch 23/50
# 49/49 [==============================] - 1s 29ms/step - loss: 1.0096 - accuracy: 0.6591 - val_loss: 1.4416 - val_accuracy: 0.4993
# Epoch 24/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.9878 - accuracy: 0.6676 - val_loss: 1.4496 - val_accuracy: 0.4927
# Epoch 25/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.9680 - accuracy: 0.6753 - val_loss: 1.4708 - val_accuracy: 0.4932
# Epoch 26/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.9479 - accuracy: 0.6835 - val_loss: 1.4598 - val_accuracy: 0.4926
# Epoch 27/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.9257 - accuracy: 0.6913 - val_loss: 1.4550 - val_accuracy: 0.4970
# Epoch 28/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.9072 - accuracy: 0.6991 - val_loss: 1.4876 - val_accuracy: 0.4914
# Epoch 29/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.8883 - accuracy: 0.7069 - val_loss: 1.4730 - val_accuracy: 0.4968
# Epoch 30/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.8684 - accuracy: 0.7134 - val_loss: 1.4841 - val_accuracy: 0.4946
# Epoch 31/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.8493 - accuracy: 0.7211 - val_loss: 1.4905 - val_accuracy: 0.4891
# Epoch 32/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.8308 - accuracy: 0.7310 - val_loss: 1.4932 - val_accuracy: 0.4924
# Epoch 33/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.8106 - accuracy: 0.7370 - val_loss: 1.4927 - val_accuracy: 0.4983
# Epoch 34/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.7913 - accuracy: 0.7452 - val_loss: 1.5040 - val_accuracy: 0.4957
# Epoch 35/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.7716 - accuracy: 0.7521 - val_loss: 1.5025 - val_accuracy: 0.4920
# Epoch 36/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.7519 - accuracy: 0.7613 - val_loss: 1.5171 - val_accuracy: 0.4915
# Epoch 37/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.7328 - accuracy: 0.7691 - val_loss: 1.5312 - val_accuracy: 0.4900
# Epoch 38/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.7152 - accuracy: 0.7759 - val_loss: 1.5407 - val_accuracy: 0.4897
# Epoch 39/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.6978 - accuracy: 0.7805 - val_loss: 1.5426 - val_accuracy: 0.4915
# Epoch 40/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.6796 - accuracy: 0.7890 - val_loss: 1.5596 - val_accuracy: 0.4905
# Epoch 41/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.6606 - accuracy: 0.7976 - val_loss: 1.5719 - val_accuracy: 0.4953
# Epoch 42/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.6422 - accuracy: 0.8039 - val_loss: 1.5825 - val_accuracy: 0.4846
# Epoch 43/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.6247 - accuracy: 0.8113 - val_loss: 1.6021 - val_accuracy: 0.4842
# Epoch 44/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.6078 - accuracy: 0.8193 - val_loss: 1.6403 - val_accuracy: 0.4853
# Epoch 45/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.5898 - accuracy: 0.8248 - val_loss: 1.6109 - val_accuracy: 0.4878
# Epoch 46/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.5731 - accuracy: 0.8328 - val_loss: 1.6339 - val_accuracy: 0.4859
# Epoch 47/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.5574 - accuracy: 0.8366 - val_loss: 1.6284 - val_accuracy: 0.4886
# Epoch 48/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.5394 - accuracy: 0.8457 - val_loss: 1.6416 - val_accuracy: 0.4820
# Epoch 49/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.5218 - accuracy: 0.8525 - val_loss: 1.6558 - val_accuracy: 0.4896
# Epoch 50/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.5060 - accuracy: 0.8580 - val_loss: 1.6626 - val_accuracy: 0.4890
# 313/313 [==============================] - 0s 1ms/step - loss: 1.6626 - accuracy: 0.4890

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""

color_bar = ["r", "g", "b", "y", "m", "k"]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.ylim([0, 5])
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# # 作業二

# %%
pred_final = model.predict(x_test)
model = keras.models.load_model("./tmp.h5")
pred_loadback = model.predict(x_test)

# %%
model.save('final_model.h5')
model.save_weights('model_weight.h5')

# %%
from sklearn.metrics import accuracy_score

final_model_acc = accuracy_score(y_true=y_test.argmax(axis=-1), y_pred=pred_final.argmax(axis=-1))
loadback_acc = accuracy_score(y_true=y_test.argmax(axis=-1), y_pred=pred_loadback.argmax(axis=-1))

print("Accuracy of final weights: %.3f" % final_model_acc)
print("Accuracy of best weights: %.3f" % loadback_acc)
# Out:
# Accuracy of final weights: 0.489
# Accuracy of best weights: 0.489

# %%
new_model = build_mlp(input_shape=x_train.shape[1:])
new_model_pred = new_model.predict(x_test)
new_model_acc = accuracy_score(y_true=y_test.argmax(axis=-1), y_pred=new_model_pred.argmax(axis=-1))
print("Accuracy of best weights: %.3f" % new_model_acc)

new_model.load_weights("./model_weight.h5")
new_model_pred = new_model.predict(x_test)
new_model_loadback_acc = accuracy_score(y_true=y_test.argmax(axis=-1), y_pred=new_model_pred.argmax(axis=-1))
print("Accuracy of best weights: %.3f" % new_model_loadback_acc)
# Out:
# Accuracy of best weights: 0.100
# Accuracy of best weights: 0.489
