# %% [markdown]
# # 作業重點
#
# 使用function y=(x+5)² 來練習學習率( leanrning rate ) 調整所造成的影響

# %% [markdown]
# # 作業目標:
#     請嘗試使用不同的組合驗證 learning rate 對所需 iteration 的影響
#     lr = [0.1, 0.0001]
#     主要驗證 Lr 對於grandient 收斂的速度

# %%
cur_x = 3 # The algorithm starts at x=3
precision = 0.000001 #This tells us when to stop the algorithm
max_iters = 10000 # maximum number of iterations
df = lambda x: 2*(x+5) #Gradient of our function

# %%
'''
需要執行初始值設定, 下列三個
# Learning rate
#iteration counter
#Step size  
'''
'''
while previous_step_size > precision and iters < max_iters:

  算法迭代更新

print("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations
'''
# Out:
# '\nwhile previous_step_size > precision and iters < max_iters:\n\n  算法迭代更新\n\nprint("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations\n'

# %%
lr = [0.1,0.00001]
iters = 0
previous_step_size = 1

iters_history = [iters]
x_history = [cur_x]

while previous_step_size > precision and iters < max_iters:
    prev_x = cur_x #Store current x value in prev_x
    cur_x = cur_x - lr[0] * df(prev_x) #Gradient descent
    previous_step_size = abs(cur_x - prev_x) # 取較大的值, Change in x
    iters = iters+1 #iteration count
    print("Iteration",iters,"\nX value is",cur_x) #Print iterations
    # Store parameters for plotting
    iters_history.append(iters)
    x_history.append(cur_x)
print("")
print("-----------")
print("lr:",lr[0],"\niters :",iters_history[-1])
print("-----------")
# Out:
# Iteration 1
# X value is 1.4
# Iteration 2
# X value is 0.11999999999999966
# Iteration 3
# X value is -0.9040000000000001
# Iteration 4
# X value is -1.7232000000000003
# Iteration 5
# X value is -2.3785600000000002
# Iteration 6
# X value is -2.902848
# Iteration 7
# X value is -3.3222784
# Iteration 8
# X value is -3.65782272
# Iteration 9
# X value is -3.926258176
# Iteration 10
# X value is -4.1410065408
# Iteration 11
# X value is -4.312805232640001
# Iteration 12
# X value is -4.450244186112
# Iteration 13
# X value is -4.5601953488896
# Iteration 14
# X value is -4.64815627911168
# Iteration 15
# X value is -4.718525023289343
# Iteration 16
# X value is -4.774820018631475
# Iteration 17
# X value is -4.81985601490518
# Iteration 18
# X value is -4.855884811924144
# Iteration 19
# X value is -4.884707849539315
# Iteration 20
# X value is -4.907766279631452
# Iteration 21
# X value is -4.926213023705161
# Iteration 22
# X value is -4.940970418964129
# Iteration 23
# ...

# %%
iters_1 = 0
cur_x_1 = 3
iters_history_1 = [iters_1]
x_history_1 = [cur_x_1]
previous_step_size_1 = 1


while previous_step_size_1 > precision and iters_1 < max_iters:
    prev_x_1 = cur_x_1 #Store current x value in prev_x
    cur_x_1 = cur_x_1 - lr[1] * df(prev_x_1) #Gradient descent
    previous_step_size_1 = abs(cur_x_1 - prev_x_1) # 取較大的值, Change in x
    iters_1 = iters_1+1 #iteration count
    print("Iteration",iters_1,"\nX value is",cur_x_1) #Print iterations
    # Store parameters for plotting
    iters_history_1.append(iters_1)
    x_history_1.append(cur_x_1)

    
print("")
print("-----------")
print("lr:",lr[1],"\niters :",iters_history_1[-1])
print("-----------")
# Out:
# Iteration 1
# X value is 2.99984
# Iteration 2
# X value is 2.9996800032
# Iteration 3
# X value is 2.999520009599936
# Iteration 4
# X value is 2.999360019199744
# Iteration 5
# X value is 2.9992000319993597
# Iteration 6
# X value is 2.9990400479987196
# Iteration 7
# X value is 2.9988800671977596
# Iteration 8
# X value is 2.9987200895964157
# Iteration 9
# X value is 2.998560115194624
# Iteration 10
# X value is 2.99840014399232
# Iteration 11
# X value is 2.9982401759894404
# Iteration 12
# X value is 2.9980802111859206
# Iteration 13
# X value is 2.997920249581697
# Iteration 14
# X value is 2.997760291176705
# Iteration 15
# X value is 2.9976003359708816
# Iteration 16
# X value is 2.9974403839641623
# Iteration 17
# X value is 2.9972804351564832
# Iteration 18
# X value is 2.9971204895477803
# Iteration 19
# X value is 2.996960547137989
# Iteration 20
# X value is 2.9968006079270464
# Iteration 21
# X value is 2.996640671914888
# Iteration 22
# X value is 2.9964807391014494
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
#適用於 Jupyter Notebook, 宣告直接在cell 內印出執行結果

plt.plot(iters_history, x_history, 'o-', ms=3, lw=1.5, color='black')
plt.xlabel(r'$iters$', fontsize=16)
plt.ylabel(r'$x$', fontsize=16)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
#適用於 Jupyter Notebook, 宣告直接在cell 內印出執行結果

plt.plot(iters_history_1, x_history_1, 'o-', ms=3, lw=1.5, color='black')
plt.xlabel(r'$iters_1$', fontsize=16)
plt.ylabel(r'$x$', fontsize=16)
plt.show()

# %%
#可以看到當lr比較大時，訓練的次數就比較少，收斂比較快
#而lr比較小時，則訓練到一萬次還未收斂。
