# %%
from tensorflow import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import RMSprop,Adam
import os

# %%
batch_size = 128 # batch 的大小，如果出現 OOM error，請降低這個值
num_classes = 10 # 類別的數量，Cifar 10 共有 10 個類別
epochs = 10 # 訓練的 epochs 數量

# 讀取資料並檢視
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# 對 label 進行 one-hot encoding (y_trian 原本是純數字)
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## 首先我們使用一般的 DNN (MLP) 來訓練
# 由於 DNN 只能輸入一維的資料，我們要先將影像進行攤平，若 (50000, 32, 32, 3) 的影像，攤平後會變成 (50000, 32*32*3) = (50000, 3072)

# %%
# 將資料攤平成一維資料
x_train = x_train.reshape(50000, 3072) 
x_test = x_test.reshape(10000, 3072)

# 將資料變為 float32 並標準化
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               1573376
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,841,162
# Trainable params: 1,841,162
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 6s 14ms/step - loss: 2.1017 - accuracy: 0.2508 - val_loss: 1.7929 - val_accuracy: 0.3670
# Epoch 2/10
# 391/391 [==============================] - 5s 13ms/step - loss: 1.8558 - accuracy: 0.3303 - val_loss: 1.7595 - val_accuracy: 0.3640
# Epoch 3/10
# 391/391 [==============================] - 6s 14ms/step - loss: 1.7825 - accuracy: 0.3562 - val_loss: 1.6696 - val_accuracy: 0.4049
# Epoch 4/10
# 391/391 [==============================] - 5s 13ms/step - loss: 1.7333 - accuracy: 0.3779 - val_loss: 1.6846 - val_accuracy: 0.4165
# Epoch 5/10
# 391/391 [==============================] - 5s 14ms/step - loss: 1.6997 - accuracy: 0.3910 - val_loss: 1.6335 - val_accuracy: 0.4156
# Epoch 6/10
# 391/391 [==============================] - 5s 14ms/step - loss: 1.6736 - accuracy: 0.3990 - val_loss: 1.6425 - val_accuracy: 0.4173
# Epoch 7/10
# 391/391 [==============================] - 6s 14ms/step - loss: 1.6562 - accuracy: 0.4068 - val_loss: 1.5726 - val_accuracy: 0.4397
# Epoch 8/10
# 391/391 [==============================] - 5s 14ms/step - loss: 1.6320 - accuracy: 0.4171 - val_loss: 1.5519 - val_accuracy: 0.4555
# Epoch 9/10
# 391/391 [==============================] - 5s 14ms/step - loss: 1.6227 - accuracy: 0.4198 - val_loss: 1.5532 - val_accuracy: 0.4517
# Epoch 10/10
# 391/391 [==============================] - 6s 14ms/step - loss: 1.6093 - accuracy: 0.4216 - val_loss: 1.5647 - val_accuracy: 0.4446
# Test loss: 1.5647413730621338
# Test accuracy: 0.444599986076355

# %% [markdown]
# ## 接下來我們使用 CNN 來訓練神經網路
# CNN 的原理非常適合處理影像類的資料，就讓我們來看看，同樣的訓練條件，CNN 是否顯著優於 DNN 呢?

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  activation_1 (Activation)   (None, 30, 30, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout_2 (Dropout)         (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  activation_2 (Activation)   (None, 15, 15, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  activation_3 (Activation)   (None, 13, 13, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_3 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense_3 (Dense)             (None, 512)               1180160
#
#  activation_4 (Activation)   (None, 512)               0
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 10)                5130
#
#  activation_5 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 47s 120ms/step - loss: 1.7490 - accuracy: 0.3645 - val_loss: 1.3450 - val_accuracy: 0.5152
# Epoch 2/10
# 391/391 [==============================] - 47s 121ms/step - loss: 1.3169 - accuracy: 0.5329 - val_loss: 1.0880 - val_accuracy: 0.6209
# Epoch 3/10
# 391/391 [==============================] - 48s 124ms/step - loss: 1.1162 - accuracy: 0.6110 - val_loss: 0.9648 - val_accuracy: 0.6600
# Epoch 4/10
# 391/391 [==============================] - 48s 123ms/step - loss: 0.9903 - accuracy: 0.6568 - val_loss: 0.8920 - val_accuracy: 0.6955
# Epoch 5/10
# 391/391 [==============================] - 47s 119ms/step - loss: 0.9061 - accuracy: 0.6859 - val_loss: 0.8617 - val_accuracy: 0.6976
# Epoch 6/10
# 391/391 [==============================] - 46s 119ms/step - loss: 0.8276 - accuracy: 0.7113 - val_loss: 0.7757 - val_accuracy: 0.7293
# Epoch 7/10
# 391/391 [==============================] - 46s 118ms/step - loss: 0.7793 - accuracy: 0.7299 - val_loss: 0.7970 - val_accuracy: 0.7230
# Epoch 8/10
# 391/391 [==============================] - 46s 118ms/step - loss: 0.7294 - accuracy: 0.7464 - val_loss: 0.7431 - val_accuracy: 0.7507
# Epoch 9/10
# 391/391 [==============================] - 47s 121ms/step - loss: 0.6959 - accuracy: 0.7593 - val_loss: 0.7052 - val_accuracy: 0.7616
# Epoch 10/10
# 391/391 [==============================] - 48s 122ms/step - loss: 0.6608 - accuracy: 0.7709 - val_loss: 0.7155 - val_accuracy: 0.7621
# Test loss: 0.715509295463562
# Test accuracy: 0.7620999813079834

# %% [markdown]
# ## 同樣運算 10 個 epochs，但 CNN 在 test data 的準確率顯著優於 DNN!

# %% [markdown]
# ## 作業
# 1. 請試著調整各個超參數，並說明那些超參數對於結果有明顯的影響?
#  filter size 或層數都會影響

# %%
## 超參數設定
import itertools
FILTER_SIZE = [2, 3]

results = {}

# %%
for i, (conv_filter_size, pool_filter_size) in enumerate(itertools.product(FILTER_SIZE, FILTER_SIZE)):
    model = Sequential()
    model.add(Conv2D(32, (conv_filter_size, conv_filter_size), padding='same',
                     input_shape=x_train.shape[1:]))
    model.add(Activation('relu'))
    model.add(Conv2D(32, (conv_filter_size, conv_filter_size)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(pool_filter_size, pool_filter_size)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (conv_filter_size, conv_filter_size), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (conv_filter_size, conv_filter_size)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(pool_filter_size, pool_filter_size)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes))
    model.add(Activation('softmax'))
    model.summary()

    model.compile(loss='categorical_crossentropy',
                  optimizer=RMSprop(),
                  metrics=['accuracy'])

    history = model.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        verbose=1,
                        validation_data=(x_test, y_test))
    score = model.evaluate(x_test, y_test, verbose=0)
    
    exp_name_tag = "conv-%s-pool-%s" % (str(conv_filter_size), str(pool_filter_size))
    results[exp_name_tag] = {'test-loss': score[0],
                             'test-acc': score[1]}
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 32, 32, 32)        416
#
#  activation_6 (Activation)   (None, 32, 32, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 31, 31, 32)        4128
#
#  activation_7 (Activation)   (None, 31, 31, 32)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 15, 15, 32)        0
#
#  conv2d_6 (Conv2D)           (None, 15, 15, 64)        8256
#
#  activation_8 (Activation)   (None, 15, 15, 64)        0
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 64)        16448
#
#  activation_9 (Activation)   (None, 14, 14, 64)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  dropout_6 (Dropout)         (None, 7, 7, 64)          0
#
#  flatten_1 (Flatten)         (None, 3136)              0
#
#  dense_5 (Dense)             (None, 512)               1606144
#
#  activation_10 (Activation)  (None, 512)               0
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 10)                5130
#
#  activation_11 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 1,640,522
# Trainable params: 1,640,522
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 36s 91ms/step - loss: 1.6867 - accuracy: 0.3873 - val_loss: 1.3008 - val_accuracy: 0.5417
# Epoch 2/10
# 391/391 [==============================] - 36s 92ms/step - loss: 1.2694 - accuracy: 0.5525 - val_loss: 1.0856 - val_accuracy: 0.6156
# Epoch 3/10
# 391/391 [==============================] - 36s 92ms/step - loss: 1.0874 - accuracy: 0.6170 - val_loss: 0.9746 - val_accuracy: 0.6572
# Epoch 4/10
# 391/391 [==============================] - 36s 92ms/step - loss: 0.9742 - accuracy: 0.6577 - val_loss: 0.8814 - val_accuracy: 0.6895
# Epoch 5/10
# 391/391 [==============================] - 38s 96ms/step - loss: 0.8895 - accuracy: 0.6905 - val_loss: 0.8138 - val_accuracy: 0.7158
# Epoch 6/10
# 391/391 [==============================] - 37s 94ms/step - loss: 0.8268 - accuracy: 0.7105 - val_loss: 0.9719 - val_accuracy: 0.6686
# Epoch 7/10
# 391/391 [==============================] - 36s 92ms/step - loss: 0.7741 - accuracy: 0.7298 - val_loss: 0.8039 - val_accuracy: 0.7229
# Epoch 8/10
# 391/391 [==============================] - 37s 93ms/step - loss: 0.7387 - accuracy: 0.7416 - val_loss: 0.7540 - val_accuracy: 0.7407
# Epoch 9/10
# 391/391 [==============================] - 36s 92ms/step - loss: 0.7045 - accuracy: 0.7554 - val_loss: 0.7665 - val_accuracy: 0.7314
# Epoch 10/10
# 391/391 [==============================] - 36s 93ms/step - loss: 0.6882 - accuracy: 0.7626 - val_loss: 0.7266 - val_accuracy: 0.7536
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 32, 32, 32)        416
#
#  activation_12 (Activation)  (None, 32, 32, 32)        0
#
#  conv2d_9 (Conv2D)           (None, 31, 31, 32)        4128
#
#  activation_13 (Activation)  (None, 31, 31, 32)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 10, 10, 32)       0
#  2D)
#
#  dropout_8 (Dropout)         (None, 10, 10, 32)        0
#
#  conv2d_10 (Conv2D)          (None, 10, 10, 64)        8256
#
#  activation_14 (Activation)  (None, 10, 10, 64)        0
#
#  conv2d_11 (Conv2D)          (None, 9, 9, 64)          16448
#
#  activation_15 (Activation)  (None, 9, 9, 64)          0
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  dropout_9 (Dropout)         (None, 3, 3, 64)          0
#
#  flatten_2 (Flatten)         (None, 576)               0
#
#  dense_7 (Dense)             (None, 512)               295424
#
#  activation_16 (Activation)  (None, 512)               0
#
#  dropout_10 (Dropout)        (None, 512)               0
#
#  dense_8 (Dense)             (None, 10)                5130
#
#  activation_17 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 329,802
# Trainable params: 329,802
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 25s 63ms/step - loss: 1.8203 - accuracy: 0.3314 - val_loss: 1.4848 - val_accuracy: 0.4565
# Epoch 2/10
# 391/391 [==============================] - 25s 63ms/step - loss: 1.4622 - accuracy: 0.4712 - val_loss: 1.5824 - val_accuracy: 0.4434
# Epoch 3/10
# 391/391 [==============================] - 25s 65ms/step - loss: 1.2851 - accuracy: 0.5373 - val_loss: 1.0883 - val_accuracy: 0.6136
# Epoch 4/10
# 391/391 [==============================] - 25s 64ms/step - loss: 1.1720 - accuracy: 0.5799 - val_loss: 1.0367 - val_accuracy: 0.6301
# Epoch 5/10
# 391/391 [==============================] - 24s 62ms/step - loss: 1.0912 - accuracy: 0.6105 - val_loss: 0.9932 - val_accuracy: 0.6439
# Epoch 6/10
# 391/391 [==============================] - 24s 62ms/step - loss: 1.0306 - accuracy: 0.6346 - val_loss: 0.9231 - val_accuracy: 0.6699
# Epoch 7/10
# 391/391 [==============================] - 24s 62ms/step - loss: 0.9838 - accuracy: 0.6525 - val_loss: 0.9763 - val_accuracy: 0.6624
# Epoch 8/10
# 391/391 [==============================] - 24s 63ms/step - loss: 0.9448 - accuracy: 0.6677 - val_loss: 0.8905 - val_accuracy: 0.6938
# Epoch 9/10
# 391/391 [==============================] - 24s 61ms/step - loss: 0.9109 - accuracy: 0.6795 - val_loss: 0.8077 - val_accuracy: 0.7224
# Epoch 10/10
# 391/391 [==============================] - 25s 63ms/step - loss: 0.8813 - accuracy: 0.6902 - val_loss: 0.8157 - val_accuracy: 0.7108
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 32, 32, 32)        896
#
#  activation_18 (Activation)  (None, 32, 32, 32)        0
#
#  conv2d_13 (Conv2D)          (None, 30, 30, 32)        9248
#
#  activation_19 (Activation)  (None, 30, 30, 32)        0
#
#  max_pooling2d_6 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  dropout_11 (Dropout)        (None, 15, 15, 32)        0
#
#  conv2d_14 (Conv2D)          (None, 15, 15, 64)        18496
#
#  activation_20 (Activation)  (None, 15, 15, 64)        0
#
#  conv2d_15 (Conv2D)          (None, 13, 13, 64)        36928
#
#  activation_21 (Activation)  (None, 13, 13, 64)        0
#
#  max_pooling2d_7 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_12 (Dropout)        (None, 6, 6, 64)          0
#
#  flatten_3 (Flatten)         (None, 2304)              0
#
#  dense_9 (Dense)             (None, 512)               1180160
#
#  activation_22 (Activation)  (None, 512)               0
#
#  dropout_13 (Dropout)        (None, 512)               0
#
#  dense_10 (Dense)            (None, 10)                5130
#
#  activation_23 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 48s 121ms/step - loss: 1.7570 - accuracy: 0.3643 - val_loss: 1.3299 - val_accuracy: 0.5202
# Epoch 2/10
# 391/391 [==============================] - 46s 118ms/step - loss: 1.3011 - accuracy: 0.5384 - val_loss: 1.1303 - val_accuracy: 0.5980
# Epoch 3/10
# 391/391 [==============================] - 47s 119ms/step - loss: 1.0896 - accuracy: 0.6182 - val_loss: 1.0125 - val_accuracy: 0.6470
# Epoch 4/10
# 391/391 [==============================] - 48s 123ms/step - loss: 0.9566 - accuracy: 0.6661 - val_loss: 0.8854 - val_accuracy: 0.6934
# Epoch 5/10
# 391/391 [==============================] - 47s 121ms/step - loss: 0.8690 - accuracy: 0.6968 - val_loss: 0.8184 - val_accuracy: 0.7235
# Epoch 6/10
# 391/391 [==============================] - 47s 121ms/step - loss: 0.8049 - accuracy: 0.7220 - val_loss: 0.7978 - val_accuracy: 0.7233
# Epoch 7/10
# 391/391 [==============================] - 47s 120ms/step - loss: 0.7521 - accuracy: 0.7394 - val_loss: 0.8379 - val_accuracy: 0.7092
# Epoch 8/10
# 391/391 [==============================] - 47s 121ms/step - loss: 0.7118 - accuracy: 0.7526 - val_loss: 0.7362 - val_accuracy: 0.7458
# Epoch 9/10
# 391/391 [==============================] - 47s 121ms/step - loss: 0.6822 - accuracy: 0.7639 - val_loss: 0.6848 - val_accuracy: 0.7665
# Epoch 10/10
# 391/391 [==============================] - 48s 123ms/step - loss: 0.6578 - accuracy: 0.7716 - val_loss: 0.7216 - val_accuracy: 0.7573
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 32, 32, 32)        896
#
#  activation_24 (Activation)  (None, 32, 32, 32)        0
#
#  conv2d_17 (Conv2D)          (None, 30, 30, 32)        9248
#
#  activation_25 (Activation)  (None, 30, 30, 32)        0
#
#  max_pooling2d_8 (MaxPooling  (None, 10, 10, 32)       0
#  2D)
#
#  dropout_14 (Dropout)        (None, 10, 10, 32)        0
#
#  conv2d_18 (Conv2D)          (None, 10, 10, 64)        18496
#
#  activation_26 (Activation)  (None, 10, 10, 64)        0
#
#  conv2d_19 (Conv2D)          (None, 8, 8, 64)          36928
#
#  activation_27 (Activation)  (None, 8, 8, 64)          0
#
#  max_pooling2d_9 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  dropout_15 (Dropout)        (None, 2, 2, 64)          0
#
#  flatten_4 (Flatten)         (None, 256)               0
#
#  dense_11 (Dense)            (None, 512)               131584
#
#  activation_28 (Activation)  (None, 512)               0
#
#  dropout_16 (Dropout)        (None, 512)               0
#
#  dense_12 (Dense)            (None, 10)                5130
#
#  activation_29 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 202,282
# Trainable params: 202,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 37s 92ms/step - loss: 1.8896 - accuracy: 0.3003 - val_loss: 1.4897 - val_accuracy: 0.4568
# Epoch 2/10
# 391/391 [==============================] - 35s 90ms/step - loss: 1.5038 - accuracy: 0.4531 - val_loss: 1.3070 - val_accuracy: 0.5209
# Epoch 3/10
# 391/391 [==============================] - 33s 85ms/step - loss: 1.3222 - accuracy: 0.5280 - val_loss: 1.2371 - val_accuracy: 0.5689
# Epoch 4/10
# 391/391 [==============================] - 33s 84ms/step - loss: 1.1889 - accuracy: 0.5802 - val_loss: 1.0345 - val_accuracy: 0.6350
# Epoch 5/10
# 391/391 [==============================] - 33s 85ms/step - loss: 1.0980 - accuracy: 0.6140 - val_loss: 0.9668 - val_accuracy: 0.6629
# Epoch 6/10
# 391/391 [==============================] - 33s 83ms/step - loss: 1.0262 - accuracy: 0.6382 - val_loss: 0.9642 - val_accuracy: 0.6579
# Epoch 7/10
# 391/391 [==============================] - 33s 84ms/step - loss: 0.9715 - accuracy: 0.6599 - val_loss: 0.9993 - val_accuracy: 0.6585
# Epoch 8/10
# 391/391 [==============================] - 33s 84ms/step - loss: 0.9369 - accuracy: 0.6743 - val_loss: 0.8448 - val_accuracy: 0.7026
# Epoch 9/10
# 391/391 [==============================] - 33s 84ms/step - loss: 0.8917 - accuracy: 0.6896 - val_loss: 0.8121 - val_accuracy: 0.7193
# Epoch 10/10
# 391/391 [==============================] - 33s 84ms/step - loss: 0.8655 - accuracy: 0.6986 - val_loss: 0.8163 - val_accuracy: 0.7183

# %% [markdown]
# 2. CNN 與 DNN 哪個模型的參數數量比較多? 造成參數的數量不同的原因在哪?

# %% [markdown]
# DNN比較多，CNN可以透過pooling跟padding層縮小特徵圖，使用的參數也會變少。
