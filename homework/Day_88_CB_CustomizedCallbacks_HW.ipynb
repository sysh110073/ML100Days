# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative
#
# ![image.png](attachment:image.png)

# %%
import os
from tensorflow import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[256, 256, 256]):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import Callback

# Record_fp_tp
class Record_tp_tn(Callback):
    """Code Here
    撰寫一個紀錄 ture positive 與 true negative 數量的 callbacks    
    """
    def __init__(self, validation_data):
        self.validation_data = validation_data

    def on_train_begin(self, epoch, logs = {}):
        logs = logs or {}
        record_items = ["val_tp", "val_tn"]
        for i in record_items:
            if i not in logs.keys():
                logs[i] = []
    
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        val_tp = sum(y_true*y_pred)
        val_tn = sum((y_true==0) & (y_pred==0))
        
        logs["val_tp"] = val_tp
        logs["val_tn"] = val_tn
        

rec_tptn = Record_tp_tn((x_test, y_test))

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

"""Code Here
將 callbacks 放入模型訓練流程中
"""
model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[rec_tptn]
          )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

"""Code Here
將 tp/tn 從訓練完的模型中取出
"""
valid_tp = model.history.history['val_tp']
valid_tn = model.history.history['val_tn']
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 256)               786688
#
#  batch_normalization_6 (Batc  (None, 256)              1024
#  hNormalization)
#
#  hidden_layer2 (Dense)       (None, 256)               65792
#
#  batch_normalization_7 (Batc  (None, 256)              1024
#  hNormalization)
#
#  hidden_layer3 (Dense)       (None, 256)               65792
#
#  batch_normalization_8 (Batc  (None, 256)              1024
#  hNormalization)
#
#  output (Dense)              (None, 10)                2570
#
# =================================================================
# Total params: 923,914
# Trainable params: 922,378
# Non-trainable params: 1,536
# _________________________________________________________________
# Epoch 1/25
# 49/49 [==============================] - 2s 33ms/step - loss: 2.2512 - accuracy: 0.2582 - val_loss: 2.1487 - val_accuracy: 0.1720 - val_tp: 0.0000e+00 - val_tn: 1000.0000
# Epoch 2/25
# 49/49 [==============================] - 1s 29ms/step - loss: 1.7560 - accuracy: 0.3831 - val_loss: 2.0070 - val_accuracy: 0.2639 - val_tp: 9.0000 - val_tn: 1000.0000
# Epoch 3/25
# 49/49 [==============================] - 1s 30ms/step - loss: 1.6332 - accuracy: 0.4235 - val_loss: 1.8494 - val_accuracy: 0.3549 - val_tp: 45.0000 - val_tn: 1000.0000
# Epoch 4/25
# 49/49 [==============================] - 1s 29ms/step - loss: 1.5603 - accuracy: 0.4514 - val_loss: 1.7225 - val_accuracy: 0.4056 - val_tp: 129.0000 - val_tn: 1000.0000
# Epoch 5/25
# 49/49 [==============================] - 1s 30ms/step - loss: 1.5083 - accuracy: 0.4693 - val_loss: 1.6406 - val_accuracy: 0.4244 - val_tp: 244.0000 - val_tn: 999.0000
# Epoch 6/25
# 49/49 [==============================] - 1s 30ms/step - loss: 1.4662 - accuracy: 0.4843 - val_loss: 1.5842 - val_accuracy: 0.4462 - val_tp: 504.0000 - val_tn: 997.0000
# Epoch 7/25
# 49/49 [==============================] - 1s 29ms/step - loss: 1.4316 - accuracy: 0.4983 - val_loss: 1.5555 - val_accuracy: 0.4527 - val_tp: 948.0000 - val_tn: 993.0000
# Epoch 8/25
# 49/49 [==============================] - 1s 29ms/step - loss: 1.4001 - accuracy: 0.5085 - val_loss: 1.5258 - val_accuracy: 0.4646 - val_tp: 1009.0000 - val_tn: 993.0000
# Epoch 9/25
# 49/49 [==============================] - 2s 34ms/step - loss: 1.3710 - accuracy: 0.5195 - val_loss: 1.5212 - val_accuracy: 0.4666 - val_tp: 1435.0000 - val_tn: 985.0000
# Epoch 10/25
# 49/49 [==============================] - 2s 39ms/step - loss: 1.3444 - accuracy: 0.5308 - val_loss: 1.5049 - val_accuracy: 0.4698 - val_tp: 1597.0000 - val_tn: 986.0000
# Epoch 11/25
# 49/49 [==============================] - 2s 32ms/step - loss: 1.3194 - accuracy: 0.5390 - val_loss: 1.4882 - val_accuracy: 0.4736 - val_tp: 1941.0000 - val_tn: 982.0000
# Epoch 12/25
# 49/49 [==============================] - 1s 29ms/step - loss: 1.2972 - accuracy: 0.5463 - val_loss: 1.4929 - val_accuracy: 0.4751 - val_tp: 1329.0000 - val_tn: 992.0000
# Epoch 13/25
# 49/49 [==============================] - 1s 28ms/step - loss: 1.2756 - accuracy: 0.5543 - val_loss: 1.4745 - val_accuracy: 0.4764 - val_tp: 1736.0000 - val_tn: 983.0000
# Epoch 14/25
# 49/49 [==============================] - 1s 28ms/step - loss: 1.2549 - accuracy: 0.5630 - val_loss: 1.4705 - val_accuracy: 0.4809 - val_tp: 1463.0000 - val_tn: 988.0000
# Epoch 15/25
# 49/49 [==============================] - 1s 28ms/step - loss: 1.2351 - accuracy: 0.5709 - val_loss: 1.4622 - val_accuracy: 0.4854 - val_tp: 2232.0000 - val_tn: 975.0000
# Epoch 16/25
# 49/49 [==============================] - 1s 27ms/step - loss: 1.2158 - accuracy: 0.5766 - val_loss: 1.4597 - val_accuracy: 0.4871 - val_tp: 1592.0000 - val_tn: 985.0000
# Epoch 17/25
# 49/49 [==============================] - 1s 28ms/step - loss: 1.1984 - accuracy: 0.5841 - val_loss: 1.4540 - val_accuracy: 0.4920 - val_tp: 1741.0000 - val_tn: 987.0000
# Epoch 18/25
# 49/49 [==============================] - 1s 28ms/step - loss: 1.1798 - accuracy: 0.5907 - val_loss: 1.4491 - val_accuracy: 0.4927 - val_tp: 1898.0000 - val_tn: 982.0000
# Epoch 19/25
# 49/49 [==============================] - 1s 29ms/step - loss: 1.1617 - accuracy: 0.5981 - val_loss: 1.4624 - val_accuracy: 0.4871 - val_tp: 2375.0000 - val_tn: 971.0000
# Epoch 20/25
# 49/49 [==============================] - 1s 28ms/step - loss: 1.1451 - accuracy: 0.6036 - val_loss: 1.4501 - val_accuracy: 0.4902 - val_tp: 1606.0000 - val_tn: 987.0000
# Epoch 21/25
# 49/49 [==============================] - 1s 28ms/step - loss: 1.1281 - accuracy: 0.6116 - val_loss: 1.4541 - val_accuracy: 0.4942 - val_tp: 1891.0000 - val_tn: 981.0000
# Epoch 22/25
# 49/49 [==============================] - 1s 29ms/step - loss: 1.1115 - accuracy: 0.6171 - val_loss: 1.4502 - val_accuracy: 0.4916 - val_tp: 2020.0000 - val_tn: 976.0000
# Epoch 23/25
# 49/49 [==============================] - 1s 28ms/step - loss: 1.0956 - accuracy: 0.6227 - val_loss: 1.4490 - val_accuracy: 0.4918 - val_tp: 2293.0000 - val_tn: 982.0000
# Epoch 24/25
# 49/49 [==============================] - 1s 28ms/step - loss: 1.0788 - accuracy: 0.6298 - val_loss: 1.4425 - val_accuracy: 0.4967 - val_tp: 1911.0000 - val_tn: 983.0000
# Epoch 25/25
# 49/49 [==============================] - 1s 29ms/step - loss: 1.0628 - accuracy: 0.6358 - val_loss: 1.4477 - val_accuracy: 0.4972 - val_tp: 2214.0000 - val_tn: 980.0000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()
